# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

# 글씨체 설정
mpl.rc('font', family='Arial')

# 데이터
labels = [
    "2010\n(age 6–18)",
    "2019\n(age 15–27)",
    "2010\n(age 15–27)",
    "2019\n(age 15–27)"
]
values = [3977.7, 3379.1, 4755.1, 3379.1]

# 그래프 그리기
plt.figure(figsize=(8, 6))
bars = plt.bar(labels, values, color='steelblue')

# 값 레이블 표시
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height + 50, f'{height}', 
             ha='center', va='bottom', fontsize=10)

# 제목 및 라벨 설정
plt.title("Sodium intake change of Korean children", fontsize=14)
plt.ylim(2000, 5000)
plt.ylabel("mg")

plt.tight_layout()
plt.show()

import matplotlib.pyplot as plt
import matplotlib as mpl

# 글꼴 설정
mpl.rc('font', family='Arial')

# 데이터
labels = [
    "2010\n(age 6–18)",
    "2019\n(age 15–27)",
    "2010\n(age 15–27)",
    "2019\n(age 15–27)"
]
values = [3977.7, 3379.1, 4755.1, 3379.1]

# 그래프 생성
plt.figure(figsize=(8, 5))
bars = plt.bar(labels, values, color='#1f77b4')  # 엑셀 기본 파랑 계열

# 텍스트 표시
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 50, f'{yval:.1f}', ha='center', fontsize=10)

# 제목과 축 설정
plt.title("Sodium intake change of Korean children", fontsize=14)
plt.ylim(2000, 5000)
plt.ylabel("mg")

# 그래프 정리 및 출력
plt.tight_layout()
plt.show()

import matplotlib.pyplot as plt
import matplotlib as mpl

# 글씨체 설정
mpl.rc('font', family='Arial')

# 데이터
labels = [
    "2010\n(age 6–18)",
    "2019\n(age 15–27)",   # 첫 번째
    "2010\n(age 15–27)",
    "2019\n(age 15–27)",   # 두 번째
    "2019\n(age 15–27)\n(extra)"
]
values = [3977.7, 3379.1, 4755.1, 3379.1, 3379.1]  # 동일한 2019 (15~27) 값 추가

# 그래프 생성
plt.figure(figsize=(9, 5))
bars = plt.bar(labels, values, color='#1f77b4')

# 값 표시
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 50, f'{height:.1f}', ha='center', fontsize=10)

# 제목, 축 설정
plt.title("Sodium intake change of Korean children", fontsize=14)
plt.ylim(2000, 5000)
plt.ylabel("mg")

plt.tight_layout()
plt.show()

import matplotlib.pyplot as plt
import matplotlib as mpl

# 글씨체 설정
mpl.rc('font', family='Arial')

# 데이터
labels = [
    "2010\n(age 6–18)",
    "2019\n(age 15–27)",
    "",  # 가운데 띄우기용 빈 칸
    "2010\n(age 15–27)",
    "2019\n(age 15–27)"
]
values = [3977.7, 3379.1, 0, 4755.1, 3379.1]

# 색 지정 (빈칸은 투명하게)
colors = ['#1f77b4', '#1f77b4', 'white', '#1f77b4', '#1f77b4']

# 그래프 생성
plt.figure(figsize=(10, 5))
bars = plt.bar(labels, values, color=colors)

# 값 표시 (빈칸 제외)
for i, bar in enumerate(bars):
    if values[i] > 0:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, height + 50, f'{height:.1f}',
                 ha='center', fontsize=10)

# 제목 및 축 설정
plt.title("Sodium intake change of Korean children", fontsize=14)
plt.ylim(2000, 5000)
plt.ylabel("mg")

plt.tight_layout()
plt.show()

import matplotlib.pyplot as plt
import matplotlib as mpl

# 글씨체 설정
mpl.rc('font', family='Arial')

# 데이터
labels = [
    "2010\n(age 6–18)",
    "2019\n(age 15–27)",
    "2010\n(age 15–27)",
    "2019\n(age 15–27)"
]
values = [3977.7, 3379.1, 4755.1, 3379.1]

# 인덱스 위치 조정 (중간에 띄우기 위해 일부러 x 위치 조정)
x_pos = [0, 1, 3, 4]  # 중간에 띄움: index 2 생략

plt.figure(figsize=(9, 5))
bars = plt.bar(x_pos, values, color='#1f77b4', width=0.6)

# X축 레이블 수동 지정
plt.xticks(x_pos, labels, fontsize=10)

# 텍스트 표시
for x, val in zip(x_pos, values):
    plt.text(x, val + 50, f'{val:.1f}', ha='center', fontsize=10)

# 기타 그래프 설정
plt.title("Sodium intake change of Korean children", fontsize=14)
plt.ylabel("mg")
plt.ylim(2000, 5000)

plt.tight_layout()
plt.show()

import matplotlib.pyplot as plt
import matplotlib as mpl

# 글씨체 설정
mpl.rc('font', family='Arial')

# 데이터
labels = [
    "2010\n(age 6–18)",
    "2019\n(age 15–27)",
    "2010\n(age 15–27)",
    "2019\n(age 15–27)"
]
values = [1911.4, 1626.4, 2171.1, 1626.4]

# x 위치를 가운데 간격 띄워 지정
x_pos = [0, 1, 3, 4]

plt.figure(figsize=(9, 5))
bars = plt.bar(x_pos, values, color='#1f77b4', width=0.6)

# 값 표시
for x, val in zip(x_pos, values):
    plt.text(x, val + 30, f'{val:.1f}', ha='center', fontsize=10)

# x축 레이블 수동 지정
plt.xticks(x_pos, labels, fontsize=10)

# 제목 및 축 설정
plt.title("Sodium intake change of Korean children\nsodium/1000kcal", fontsize=14)
plt.ylabel("mg / 1000kcal")
plt.ylim(500, 2500)

plt.tight_layout()
plt.show()

import matplotlib.pyplot as plt
import matplotlib as mpl

# 글꼴 설정
mpl.rc('font', family='Arial')

# 데이터
labels = [
    "2010\n(age 6–18)",
    "2019\n(age 15–27)",
    "2010\n(age 15–27)",
    "2019\n(age 15–27)"
]
values = [13.34, 26.22, 11.15, 26.22]

# x 위치를 가운데 띄워 지정
x_pos = [0, 1, 3, 4]

# 그래프 생성
plt.figure(figsize=(9, 5))
bars = plt.bar(x_pos, values, color='#e66b2b', width=0.6)

# 값 표시
for x, val in zip(x_pos, values):
    plt.text(x, val + 1, f'{val:.2f}', ha='center', fontsize=10)

# X축 레이블 수동 설정
plt.xticks(x_pos, labels, fontsize=10)

# 제목 및 축 설정
plt.title("% Korean children consuming less than\nsodium intake goal", fontsize=14)
plt.ylabel("%")
plt.ylim(0, 35)

plt.tight_layout()
plt.show()
