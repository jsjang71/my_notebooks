# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

# 글씨체 설정
mpl.rc('font', family='Arial')

# 데이터 정의
data = pd.DataFrame({
    'Year': [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019],
    '1~9 years': [2305.8, 2338.9, 2213.2, 2008.9, 1990.5, 2070.0, 1828.3, 1839.7, 1749.0, 1874.5],
    '10~18 years': [4324.3, 4122.0, 4222.3, 3470.8, 3534.3, 3552.5, 3161.4, 3088.8, 3165.9, 3105.0],
    '19~29 years': [4912.7, 4946.9, 4778.0, 4144.6, 4035.4, 4168.9, 3642.1, 3515.0, 3442.9, 3395.8],
    '30~39 years': [5784.9, 5651.9, 5298.0, 4675.1, 4394.3, 4507.3, 3930.8, 3820.2, 3651.2, 3686.8],
    '40~49 years': [5564.2, 5843.1, 5435.3, 4356.9, 4264.8, 4528.8, 3738.0, 3956.7, 3743.5, 3687.3],
    '50~59 years': [5393.9, 5238.3, 4872.3, 4121.7, 4032.7, 4233.1, 3501.5, 3520.2, 3549.7, 3373.5],
    '60~69 years': [4609.4, 4582.4, 4466.5, 3614.6, 3598.4, 3550.3, 3191.3, 3206.0, 3155.1, 3277.8],
    '>=70 years': [3840.2, 3438.7, 3545.4, 2960.1, 2722.1, 2940.1, 2509.5, 2545.4, 2641.9, 2568.5]
})

# 꺾은선 그래프 생성
plt.figure(figsize=(12, 7))
for column in data.columns[1:]:
    plt.plot(data['Year'], data[column], marker='o', label=column)

# 제목, 축 라벨, 범례 등 설정
plt.title('Sodium intake by age groups 2010-2019')
plt.xlabel('Year')
plt.ylabel('Sodium Intake (mg)')
plt.xticks(data['Year'])
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=4, frameon=False)
plt.grid(axis='y')

# 그래프 출력
plt.show()
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl

# 글씨체 설정
mpl.rc('font', family='Arial')

# 데이터 정의 (예시: 연령별 sodium intake)
data = pd.DataFrame({
    'Year': [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019],
    '1~9 years': [2305.8, 2338.9, 2213.2, 2008.9, 1990.5, 2070.0, 1828.3, 1839.7, 1749.0, 1874.5],
    '10~18 years': [4324.3, 4122.0, 4222.3, 3470.8, 3534.3, 3552.5, 3161.4, 3088.8, 3165.9, 3105.0],
    '19~29 years': [4912.7, 4946.9, 4778.0, 4144.6, 4035.4, 4168.9, 3642.1, 3515.0, 3442.9, 3395.8],
    '30~39 years': [5784.9, 5651.9, 5298.0, 4675.1, 4394.3, 4507.3, 3930.8, 3820.2, 3651.2, 3686.8],
    '40~49 years': [5564.2, 5843.1, 5435.3, 4356.9, 4264.8, 4528.8, 3738.0, 3956.7, 3743.5, 3687.3],
    '50~59 years': [5393.9, 5238.3, 4872.3, 4121.7, 4032.7, 4233.1, 3501.5, 3520.2, 3549.7, 3373.5],
    '60~69 years': [4609.4, 4582.4, 4466.5, 3614.6, 3598.4, 3550.3, 3191.3, 3206.0, 3155.1, 3277.8],
    '>=70 years': [3840.2, 3438.7, 3545.4, 2960.1, 2722.1, 2940.1, 2509.5, 2545.4, 2641.9, 2568.5]
})

# 다중 꺾은선 그래프 + shading
plt.figure(figsize=(14, 8))

# 기준이 되는 연령 그룹 설정 (예: 30~39세)
ref_group = '30~39 years'

# 모든 그룹에 대해 그래프를 그리고, 기준 그룹과의 차이를 음영으로 표시
for col in data.columns[1:]:
    plt.plot(data['Year'], data[col], label=col, marker='o')
    if col != ref_group:
        plt.fill_between(data['Year'], data[col], data[ref_group], alpha=0.1)

plt.title('Sodium intake by Age Groups with Shading Compared to 30~39 years (2010–2019)')
plt.xlabel('Year')
plt.ylabel('Sodium Intake (mg)')
plt.xticks(data['Year'])
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=4, frameon=False)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl

# 글씨체 설정
mpl.rc('font', family='Arial')

# 데이터 정의 (예시: 연령별 sodium intake)
data = pd.DataFrame({
    'Year': [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019],
    '1~9 years': [2305.8, 2338.9, 2213.2, 2008.9, 1990.5, 2070.0, 1828.3, 1839.7, 1749.0, 1874.5],
    '10~18 years': [4324.3, 4122.0, 4222.3, 3470.8, 3534.3, 3552.5, 3161.4, 3088.8, 3165.9, 3105.0],
    '19~29 years': [4912.7, 4946.9, 4778.0, 4144.6, 4035.4, 4168.9, 3642.1, 3515.0, 3442.9, 3395.8],
    '30~39 years': [5784.9, 5651.9, 5298.0, 4675.1, 4394.3, 4507.3, 3930.8, 3820.2, 3651.2, 3686.8],
    '40~49 years': [5564.2, 5843.1, 5435.3, 4356.9, 4264.8, 4528.8, 3738.0, 3956.7, 3743.5, 3687.3],
    '50~59 years': [5393.9, 5238.3, 4872.3, 4121.7, 4032.7, 4233.1, 3501.5, 3520.2, 3549.7, 3373.5],
    '60~69 years': [4609.4, 4582.4, 4466.5, 3614.6, 3598.4, 3550.3, 3191.3, 3206.0, 3155.1, 3277.8],
    '>=70 years': [3840.2, 3438.7, 3545.4, 2960.1, 2722.1, 2940.1, 2509.5, 2545.4, 2641.9, 2568.5]
})

# 다중 꺾은선 그래프 + shading
plt.figure(figsize=(14, 8))

# 기준이 되는 연령 그룹 설정 (예: 30~39세)
ref_group = '30~39 years'

# 모든 그룹에 대해 그래프를 그리고, 기준 그룹과의 차이를 음영으로 표시
for col in data.columns[1:]:
    plt.plot(data['Year'], data[col], label=col, marker='o')
    if col != ref_group:
        plt.fill_between(data['Year'], data[col], data[ref_group], alpha=0.1)

plt.title('Sodium intake by Age Groups with Shading Compared to 30~39 years (2010–2019)')
plt.xlabel('Year')
plt.ylabel('Sodium Intake (mg)')
plt.xticks(data['Year'])
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), ncol=4, frameon=False)  # 간격 좁힘
plt.grid(axis='y')
plt.tight_layout()
plt.show()

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

# 글씨체 설정
mpl.rc('font', family='Arial')

# 데이터 정의 (예시: 연령별 sodium intake)
data = pd.DataFrame({
    'Year': [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019],
    '1~9 years': [2305.8, 2338.9, 2213.2, 2008.9, 1990.5, 2070.0, 1828.3, 1839.7, 1749.0, 1874.5],
    '10~18 years': [4324.3, 4122.0, 4222.3, 3470.8, 3534.3, 3552.5, 3161.4, 3088.8, 3165.9, 3105.0],
    '19~29 years': [4912.7, 4946.9, 4778.0, 4144.6, 4035.4, 4168.9, 3642.1, 3515.0, 3442.9, 3395.8],
    '30~39 years': [5784.9, 5651.9, 5298.0, 4675.1, 4394.3, 4507.3, 3930.8, 3820.2, 3651.2, 3686.8],
    '40~49 years': [5564.2, 5843.1, 5435.3, 4356.9, 4264.8, 4528.8, 3738.0, 3956.7, 3743.5, 3687.3],
    '50~59 years': [5393.9, 5238.3, 4872.3, 4121.7, 4032.7, 4233.1, 3501.5, 3520.2, 3549.7, 3373.5],
    '60~69 years': [4609.4, 4582.4, 4466.5, 3614.6, 3598.4, 3550.3, 3191.3, 3206.0, 3155.1, 3277.8],
    '>=70 years': [3840.2, 3438.7, 3545.4, 2960.1, 2722.1, 2940.1, 2509.5, 2545.4, 2641.9, 2568.5]
})

# 다중 꺾은선 그래프
plt.figure(figsize=(14, 8))

# 각 연령대 꺾은선 그래프 그리기
for col in data.columns[1:]:
    plt.plot(data['Year'], data[col], label=col, marker='o')

plt.title('Sodium intake by Age Groups 2010–2019', fontsize=18)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Sodium Intake (mg)', fontsize=14)
plt.xticks(data['Year'], fontsize=12)
plt.yticks(fontsize=12)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), ncol=4, frameon=False, fontsize=12)
plt.grid(axis='y')
plt.tight_layout()
plt.show()
