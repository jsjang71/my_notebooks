# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

# 글꼴 설정
mpl.rc('font', family='Arial')

# 데이터 입력
years = list(range(2010, 2020))
lowest = [4608.5, 4640.0, 4269.7, 3650.6, 3576.5, 3676.8, 3172.8, 3153.0, 3069.0, 3123.0]
mid_low = [4733.3, 4847.8, 4696.2, 3914.4, 3690.1, 3698.5, 3331.8, 3279.0, 3345.4, 3151.6]
middle = [4957.9, 4847.9, 4696.7, 3843.0, 3816.7, 4018.8, 3423.9, 3503.1, 3224.8, 3262.0]
mid_high = [4921.1, 4805.2, 4738.5, 3758.8, 3706.3, 4003.8, 3263.0, 3357.3, 3316.0, 3290.0]
highest = [5034.9, 4813.1, 4608.1, 4127.2, 4004.2, 4107.0, 3515.6, 3414.7, 3437.6, 3392.2]

# 그래프 생성
plt.figure(figsize=(10, 6))

plt.plot(years, lowest, marker='o', label='Lowest')
plt.plot(years, mid_low, marker='^', label='Mid-low')
plt.plot(years, middle, marker='s', label='Middle')
plt.plot(years, mid_high, marker='*', label='Mid-high')
plt.plot(years, highest, marker='x', label='Highest')

# 그래프 설정
plt.title('Sodium intake change 2010–2019\nby income level', fontsize=14)
plt.xlabel('Year')
plt.ylabel('Sodium intake (mg)')
plt.xticks(years)
plt.ylim(2000, 5500)
plt.grid(axis='y', linestyle='--', alpha=0.7)  # y축만 표시
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=5, frameon=False)
plt.tight_layout()

plt.show()

import matplotlib.pyplot as plt
import matplotlib as mpl

# 글꼴 설정
mpl.rc('font', family='Arial')

# 데이터 입력
years = list(range(2010, 2020))
lowest = [4608.5, 4640.0, 4269.7, 3650.6, 3576.5, 3676.8, 3172.8, 3153.0, 3069.0, 3123.0]
mid_low = [4733.3, 4847.8, 4696.2, 3914.4, 3690.1, 3698.5, 3331.8, 3279.0, 3345.4, 3151.6]
middle = [4957.9, 4847.9, 4696.7, 3843.0, 3816.7, 4018.8, 3423.9, 3503.1, 3224.8, 3262.0]
mid_high = [4921.1, 4805.2, 4738.5, 3758.8, 3706.3, 4003.8, 3263.0, 3357.3, 3316.0, 3290.0]
highest = [5034.9, 4813.1, 4608.1, 4127.2, 4004.2, 4107.0, 3515.6, 3414.7, 3437.6, 3392.2]

# 그래프 생성
plt.figure(figsize=(10, 6))

plt.plot(years, lowest, marker='o', label='Lowest')
plt.plot(years, mid_low, marker='^', label='Mid-low')
plt.plot(years, middle, marker='s', label='Middle')
plt.plot(years, mid_high, marker='*', label='Mid-high')
plt.plot(years, highest, marker='x', label='Highest')

# 그래프 설정
plt.title('Sodium intake change 2010–2019\nby income level', fontsize=14)
plt.xlabel('Year')
plt.ylabel('Sodium intake (mg)')
plt.xticks(years)
plt.ylim(2000, 5500)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.08), ncol=5, frameon=False)  # 간격 좁힘
plt.tight_layout()

plt.show()
